# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("Students_marks.csv")

# %%
data
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Roll No.          10 non-null     int64
#  1   Name              10 non-null     object
#  2   Gender            10 non-null     object
#  3   Data Structure    10 non-null     int64
#  4   Mathematics       10 non-null     int64
#  5   Operating System  10 non-null     int64
#  6   Average marks     10 non-null     float64
#  7   Ranking           10 non-null     object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 772.0+ bytes

# %%
data.describe()
# Out:
#        Roll No.  Data Structure  Mathematics  Operating System  Average marks
# count  10.00000       10.000000     10.00000         10.000000      10.000000
# mean    5.50000       40.700000     23.10000         20.600000      28.131000
# std     3.02765       52.493492      3.60401          6.619836      19.337093
# min     1.00000       21.000000     18.00000          9.000000      18.000000
# 25%     3.25000       23.000000     21.25000         15.500000      20.330000
# 50%     5.50000       24.000000     22.50000         21.500000      22.665000
# 75%     7.75000       25.750000     24.75000         26.500000      24.997500
# max    10.00000      190.000000     30.00000         28.000000      82.660000

# %%
data.isnull().sum()
# Out:
# Roll No.            0
# Name                0
# Gender              0
# Data Structure      0
# Mathematics         0
# Operating System    0
# Average marks       0
# Ranking             0
# dtype: int64

# %%
data
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
plt.plot(data["Name"] , data["Mathematics"])
plt.title("mathamatics marks ")
plt.xlabel("student_name")
plt.ylabel("marks")
plt.show()

# %%
plt.bar(data["Name"] , data["Mathematics"])
plt.title("mathamatics marks ")
plt.xlabel("student_name")
plt.ylabel("marks")
plt.show()

# %%
plt.plot(data["Name"] , data["Operating System"])
plt.title("operating system marks ")
plt.xlabel("student_name")
plt.ylabel("marks")
plt.show()

# %%
plt.barh(data["Name"] , data["Operating System"])
plt.title("operating system marks ")
plt.xlabel("student_name")
plt.ylabel("marks")
plt.show()
